# %%
from keras.applications.vgg16 import VGG16

# %%
model = VGG16()

model.summary()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 18s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.utils import load_img
from keras.applications.imagenet_utils import preprocess_input
import numpy as np

# %%
image=load_img('/content/drive/MyDrive/CHANDRU M D_PROITBRIDGE/SCRIPTS/Deep_Learning/Day_09/Dog_Breeds.jpg',target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image=np.array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
#reshape
image = image.reshape(1,image.shape[0],image.shape[1],image.shape[2])

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
image = preprocess_input(image)

# %%
image
# Out:
# array([[[[ -55.939003,  -38.779   ,  -80.68    ],
#          [ -55.939003,  -38.779   ,  -80.68    ],
#          [ -55.939003,  -38.779   ,  -80.68    ],
#          ...,
#          [ -84.939   ,  -89.779   , -119.68    ],
#          [ -85.939   ,  -92.779   , -118.68    ],
#          [ -85.939   ,  -92.779   , -118.68    ]],
#
#         [[ -55.939003,  -38.779   ,  -80.68    ],
#          [ -55.939003,  -38.779   ,  -80.68    ],
#          [ -55.939003,  -38.779   ,  -80.68    ],
#          ...,
#          [ -85.939   ,  -91.779   , -119.68    ],
#          [ -85.939   ,  -92.779   , -118.68    ],
#          [ -86.939   ,  -93.779   , -119.68    ]],
#
#         [[ -55.939003,  -38.779   ,  -80.68    ],
#          [ -55.939003,  -38.779   ,  -80.68    ],
#          [ -55.939003,  -38.779   ,  -80.68    ],
#          ...,
#          [ -86.939   ,  -92.779   , -120.68    ],
#          [ -86.939   ,  -93.779   , -119.68    ],
#          [ -87.939   ,  -94.779   , -120.68    ]],
#
# ...

# %%
pred = model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
pred
# Out:
# array([[4.66766714e-08, 5.52746151e-08, 8.47374722e-08, 1.34191591e-08,
#         2.72958331e-08, 7.35664543e-08, 2.04462847e-08, 1.35529731e-07,
#         2.02011904e-07, 3.89606356e-08, 4.89735825e-08, 9.47195133e-07,
#         4.22679278e-07, 2.08765641e-07, 2.15509473e-07, 6.83407606e-08,
#         3.53941260e-07, 1.42070249e-07, 8.55763886e-08, 2.80108935e-07,
#         3.25029959e-07, 1.09354026e-07, 3.07929184e-07, 4.61638791e-07,
#         1.55579926e-06, 5.69458507e-08, 3.51539917e-08, 9.14627734e-08,
#         3.80660268e-08, 3.66081601e-08, 6.02069505e-08, 2.54104236e-07,
#         3.45246534e-08, 4.23423003e-08, 7.75749029e-08, 1.76506614e-08,
#         6.67603217e-08, 3.84272738e-08, 3.31046515e-08, 1.37874764e-07,
#         4.03241444e-07, 2.24852954e-08, 4.71501949e-08, 5.95676397e-08,
#         2.28325483e-08, 2.18160778e-08, 4.73395943e-07, 1.64398116e-07,
#         7.16483726e-08, 6.47478089e-08, 1.08570305e-07, 1.45243568e-08,
# ...

# %%
from keras.applications.vgg16 import decode_predictions #it will predict the output

# %%
op = decode_predictions(pred)

# %%
op
# Out:
# [[('n02099601', 'golden_retriever', np.float32(0.85945886)),
#   ('n02104029', 'kuvasz', np.float32(0.03510013)),
#   ('n02111500', 'Great_Pyrenees', np.float32(0.027270418)),
#   ('n02101556', 'clumber', np.float32(0.013388993)),
#   ('n02108551', 'Tibetan_mastiff', np.float32(0.009823447))]]

# %%
image_2 = load_img("/content/drive/MyDrive/CHANDRU M D_PROITBRIDGE/SCRIPTS/Deep_Learning/Day_09/images (1).jpeg",target_size=(224,224))

# %%
image_2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image_2 = np.array(image_2)

# %%
image_2.shape
# Out:
# (224, 224, 3)

# %%
#again reshaping

# %%
image_2 = image_2.reshape(1,image_2.shape[0],image_2.shape[1],image_2.shape[2])

# %%
image_2.shape
# Out:
# (1, 224, 224, 3)

# %%
image_2 = preprocess_input(image_2)

# %%
pred_2 = model.predict(image_2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
op_2 = decode_predictions(pred_2)

# %%
op_2
# Out:
# [[('n02749479', 'assault_rifle', np.float32(0.7046813)),
#   ('n04090263', 'rifle', np.float32(0.28757685)),
#   ('n04086273', 'revolver', np.float32(0.0047789924)),
#   ('n02879718', 'bow', np.float32(0.0012060032)),
#   ('n03527444', 'holster', np.float32(0.00044798266))]]
