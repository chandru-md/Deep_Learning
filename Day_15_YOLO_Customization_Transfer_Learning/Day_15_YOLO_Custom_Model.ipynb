# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17777, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 17777 (delta 98), reused 55 (delta 54), pack-reused 17616 (from 2)
# Receiving objects: 100% (17777/17777), 17.14 MiB | 20.19 MiB/s, done.
# Resolving deltas: 100% (12076/12076), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.2 MB/s eta 0:00:00
# ...

# %%
# !wget https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt
# Out:
# --2025-12-29 14:38:46--  https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
train_path = "/content/drive/MyDrive/CHANDRU M D_PROITBRIDGE/SCRIPTS/Deep_Learning/Day_15_YOLO_Customization/Train/images"
val_path = "/content/drive/MyDrive/CHANDRU M D_PROITBRIDGE/SCRIPTS/Deep_Learning/Day_15_YOLO_Customization/val/images"

# %%
# !python train.py --img 416 --batch 8 --epochs 3 --data /content/Modified_coco.yaml --weights /content/yolov5/yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-12-29 14:58:05.439146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767020285.467007    6742 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767020285.475259    6742 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767020285.499756    6742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python detect.py --source /content/maksssksksss518.png --weights /content/yolov5/runs/train/exp2/weights/last.pt --img 416 --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/last.pt'], source=/content/maksssksksss518.png, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-453-geed9bc19 Python-3.12.12 torch-2.9.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/maksssksksss518.png: 256x416 11 Masks, 148.4ms
# Speed: 1.0ms pre-process, 148.4ms inference, 1.2ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp3
# 1 labels saved to runs/detect/exp3/labels
